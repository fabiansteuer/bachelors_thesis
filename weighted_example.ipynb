# %%
# %pylab inline --no-import-all

import time
from TempGraph import TempGraph
import matplotlib.pyplot as plt
import networkx as nx

from matplotlib import rc
rc('font',
   **{#'family':'sans-serif',
      #'sans-serif':['sans-serif'],
      'family':'serif',
      'serif':['Palatino'],
      'size':22
      })
rc('text',
   usetex=True)
rc('figure',
   **{'figsize':(16,9),
      'dpi':300}
   )

path='../data/old/test/1/'

G = TempGraph()
G.create_graph(path=path)
#G.draw_temporal(figsize=(16, 9), arrows=False)
#G.draw_all_layouts()
pos = nx.circular_layout(G)
G.draw_weighted(figsize=(16,9))
plt.savefig('../graphics/weighted_example.pdf')
plt.savefig('../graphics/weighted_example.png', dpi=150)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [2, 3, 1, 1, 5, 1, 3]
# [ 3.5   5.25  1.75  1.75  8.75  1.75  5.25]
