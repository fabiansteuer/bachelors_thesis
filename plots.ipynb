# %% [markdown]
# # share_method

# %%
# %pylab inline --no-import-all

import time
from matplotlib import style
# Set style for plotting
style.use('ggplot')
#['dark_background', 'fivethirtyeight', 'ggplot', 'bmh', 'grayscale']

from matplotlib import rc
rc('font',
   **{#'family':'sans-serif',
      #'sans-serif':['sans-serif'],
      'family':'serif',
      'serif':['Palatino'],
      'size':22
      })
rc('text',
   usetex=True)
rc('figure',
   **{'figsize':(16,9),
      'dpi':300}
   )


path='../graphics/'
x = np.linspace(0, 1, 1000)
y = np.concatenate((np.linspace(0, 2, 10), np.linspace(2, 0, 990)))


plt.figure(dpi=500)
plt.xlim(-0.005, 1.005)
plt.ylim(-0.02, 2.02)
plt.xlabel(r'Share ratio')
plt.ylabel(r'Probability density')
plt.plot(x, y, lw=2, color='black')
plt.fill_between(x, y, color='grey')
plt.savefig(path + 'share_method.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
