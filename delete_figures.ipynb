# %%
# %pylab inline --no-import-all

import os
import shutil

for root, dirs, files in os.walk('../data/speed/100'):
    print(root)
    if root.endswith('figures') and not root.endswith('0/figures'):
        shutil.rmtree(root)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ../data/speed/100
# ../data/speed/100/65
# ../data/speed/100/65/figures
# ../data/speed/100/28
# ../data/speed/100/28/figures
# ../data/speed/100/95
# ../data/speed/100/95/figures
# ../data/speed/100/6
# ../data/speed/100/6/figures
# ../data/speed/100/32
# ../data/speed/100/32/figures
# ../data/speed/100/55
# ../data/speed/100/55/figures
# ../data/speed/100/81
# ../data/speed/100/81/figures
# ../data/speed/100/2
# ../data/speed/100/2/figures
# ../data/speed/100/5
# ../data/speed/100/5/figures
# ../data/speed/100/21
# ../data/speed/100/21/figures
# ../data/speed/100/75
# ../data/speed/100/75/figures
# ../data/speed/100/54
# ../data/speed/100/54/figures
# ../data/speed/100/67
# ../data/speed/100/67/figures
# ../data/speed/100/40
# ../data/speed/100/40/figures
# ../data/speed/100/45
# ../data/speed/100/45/figures
# ../data/speed/100/46
# ../data/speed/100/46/figures
# ../data/speed/100/24
# ../data/speed/100/24/figures
# ...
