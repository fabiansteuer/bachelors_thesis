# %%
# %pylab inline --no-import-all

import os
import time
import numpy as np
from GraphSeries import GraphSeries
import matplotlib.pyplot as plt
#import networkx as nx

from matplotlib import rc
rc('font',
   **{#'family':'sans-serif',
      #'sans-serif':['sans-serif'],
      'family':'serif',
      'serif':['Palatino'],
      'size':22
      })
rc('text',
   usetex=True)
rc('figure',
   **{'figsize':(16,9),
      'dpi':300}
   )

path = '../data/speed/'

folders = sorted([folder
                  for folder in os.listdir(path)
                  if folder.isdigit()
                  ],
                  key=lambda x: int(x)
                  )
for folder in folders:
    with open(path + folder + '/pickups.txt') as file:
        data = file.readline().split()
        print(data)
        if int(folder) in [80, 100]: continue
        #plt.gca().set_yscale('log')
        plt.errorbar(int(folder), float(data[0]), yerr=float(data[1]), fmt='o', linewidth=3, label=str(folder))
        plt.xlabel(r'Speed factor')
        plt.ylabel(r'Total number of pickups')
        #plt.legend(title='Step factor', numpoints=1)
        
# Adjust axes limits
xlims = list(plt.gca().get_xlim())
xlims[0] = xlims[0] - (xlims[1]-xlims[0])*0.01*9/16
xlims[1] = xlims[1] + (xlims[1]-xlims[0])*0.01*9/16
plt.xlim(xlims)
ylims = list(plt.gca().get_ylim())
ylims[0] = ylims[0] - (ylims[1]-ylims[0])*0.01
ylims[1] = ylims[1] + (ylims[1]-ylims[0])*0.01
plt.ylim(ylims)

plt.tight_layout()
plt.savefig(path + 'n_pickups.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ['276.57', '12.7681282888']
# ['245.26', '10.9092804529']
# ['234.12', '10.6379321299']
# ['225.43', '10.34239334']
# ['220.91', '9.51745239021']
# ['209.86', '8.76700633056']
# ['205.99', '8.82439233035']
# ['205.76', '7.92731984973']
# ['204.44', '9.03694638692']
# ['203.98', '8.6948030455']
# ['204.58', '9.20019565009']
# ['203.48', '8.93586033911']
# ['204.65', '8.553800325']
