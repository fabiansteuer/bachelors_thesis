# %% [markdown]
# ### Graph series analysis: 100
#
# number of ants: 100
# grid length: 15
# interaction time: 100
# share: triangular (0.1)
# supply ratio: 1.0
# walk_probability: 0.8

# %% [markdown]
# ### Description of the graphs
# The following graphs show the data for 100 ant nests with 100 ants each. Coloured lines denote the average for each nest and the black line the average of the 100 nests. Some averages still have to be calculated and are therefore not available yet.

# %%
# %pylab inline --no-import-all

from GraphSeries import GraphSeries
import matplotlib.pyplot as plt

from matplotlib import rc
rc('font',
   **{#'family':'sans-serif',
      #'sans-serif':['sans-serif'],
      'family':'serif',
      'serif':['Palatino'],
      'size':18
      })
rc('text',
   usetex=True)
rc('figure',
   **{'figsize':(16,9),
      'dpi':300}
   )


path='../data/velocase/v1/'

S = GraphSeries(path=path)
#S.analyze()

S.plot_fed()
plt.savefig('plot_fed.pdf')
S.plot_n_given()
plt.savefig('plot_n_given.pdf')
S.plot_n_reached()
plt.savefig('plot_fed.pdf')
S.plot_degree_histogramm()
plt.savefig('degree_histogramm.pdf')
S.calc_avg_emptytime()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [6038, 5376, 5044, 5380, 5470, 6296, 6150, 5983, 5648, 5900]
# Average: 5728.500000
# Standard deviation: 384.349125
